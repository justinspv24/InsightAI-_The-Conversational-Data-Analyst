# %% [markdown]
# Many "Chat with your Data" tools fail because they directly ask a Large Language Model (LLM) to perform complex calculations. Since LLMs are unreliable with math, they tend to hallucinate when dealing with large datasets. The effective solution is to have the AI generate the necessary code (like Python) to perform the computation accurately, rather than calculating it itself.
#
# This approach builds a robust Personal AI Data Analyst by:
#
# Ingesting flat data files (CSV, Excel, JSON).
#
# Detecting column types (Numeric, Categorical).
#
# Reasoning to translate natural language questions (e.g., "Show me the outliers") into executable Python code.
#
# Executing the code in a safe environment and returning the precise result.
#
# This method effectively merges the AI's language understanding with Python's mathematical precision.

# %% [markdown]
# Prerequisites

# %%
pip install streamlit pandas matplotlib numpy scipy openpyxl
# Out:
# Collecting streamlit
#   Downloading streamlit-1.51.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: pandas in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (2.3.2)
# Requirement already satisfied: matplotlib in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (3.10.6)
# Requirement already satisfied: numpy in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (2.3.3)
# Requirement already satisfied: scipy in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (1.16.2)
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting altair!=5.4.0,!=5.4.1,<6,>=4.0 (from streamlit)
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<7,>=4.0 (from streamlit)
#   Using cached cachetools-6.2.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting click<9,>=7.0 (from streamlit)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: packaging<26,>=20 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from streamlit) (25.0)
# Requirement already satisfied: pillow<13,>=7.1.0 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from streamlit) (11.3.0)
# Collecting protobuf<7,>=3.20 (from streamlit)
#   Downloading protobuf-6.33.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting pyarrow<22,>=7.0 (from streamlit)
#   Downloading pyarrow-21.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: requests<3,>=2.27 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from streamlit) (2.32.5)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from streamlit) (4.15.0)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from streamlit) (6.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: jinja2 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Collecting narwhals>=1.14.2 (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit)
#   Downloading narwhals-2.13.0-py3-none-any.whl.metadata (12 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from matplotlib) (3.2.4)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.27.1)
# Requirement already satisfied: six>=1.5 in /home/pv_linux/miniforge3/envs/ai/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading streamlit-1.51.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 12.8 MB/s  0:00:00eta 0:00:01
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.2/731.2 kB 10.1 MB/s  0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached cachetools-6.2.2-py3-none-any.whl (11 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading protobuf-6.33.1-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
# Downloading pyarrow-21.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (42.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 11.8 MB/s  0:00:03m0:00:0100:01
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 12.1 MB/s  0:00:00 eta 0:00:01
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading narwhals-2.13.0-py3-none-any.whl (426 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: watchdog, toml, tenacity, smmap, pyarrow, protobuf, narwhals, et-xmlfile, click, cachetools, blinker, pydeck, openpyxl, gitdb, gitpython, altair, streamlit
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/17 [streamlit]17 [streamlit]
# Successfully installed altair-5.5.0 blinker-1.9.0 cachetools-6.2.2 click-8.3.1 et-xmlfile-2.0.0 gitdb-4.0.12 gitpython-3.1.45 narwhals-2.13.0 openpyxl-3.1.5 protobuf-6.33.1 pyarrow-21.0.0 pydeck-0.9.1 smmap-5.0.2 streamlit-1.51.0 tenacity-9.1.2 toml-0.10.2 watchdog-6.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !ollama pull llama3.1
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest
# pulling 667b0c1932bc: 100% ▕██████████████████▏ 4.9 GB
# pulling 948af2743fc7: 100% ▕██████████████████▏ 1.5 KB
# pulling 0ba8f0e314b4: 100% ▕██████████████████▏  12 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 455f34728c9b: 100% ▕██████████████████▏  487 B
# verifying sha256 digest
# writing manifest
# success

# %%
curl -fsSL https://ollama.com/install.sh | sh
ollama serve
# Out:
#   Cell In[4], line 1
#     curl -fsSL https://ollama.com/install.sh | sh
#                ^
# SyntaxError: invalid syntax

# %%
# !echo "Explain the difference between a list and a tuple in Python." | ollama run llama3.1
# Out:
# ⠙ ⠹ ⠹ **Lists vs Tuples in Python**
# ====================================
#
# In Python, `list` and `tuple` are two types of data structures that can be
# used to store collections of items. While they share some similarities, the
# there are key differences between them.
#
# **List**
# --------
#
# A list is a collection of items that can be changed (i.e., modified) after
# creation. Lists are denoted by square brackets `[]` and use the syntax `lis
# `list_name = [item1, item2, ...]`.
#
# *   Can be modified after creation using indexing, slicing, or the `append(
# `append()` method.
# *   Order of items is preserved.
# *   Can store duplicate values.
#
# **Tuple**
# ---------
#
# A tuple is a collection of items that cannot be changed (i.e., modified) af
# after creation. Tuples are denoted by parentheses `()` and use the syntax `
# `tuple_name = (item1, item2, ...)`.
# *   Cannot be modified after creation.
# *   Order of items is preserved.
# *   Can store duplicate values.
#
# **Key differences**
# --------------------
#
# Here's a summary of the main differences between lists and tuples:
#
# | **Property** | **List** | **Tuple** |
# | --- | --- | --- |
# | **Modifiability** | Mutable (can be changed) | Immutable (cannot be chang
# changed) |
# | **Syntax** | `[item1, item2, ...]` | `(item1, item2, ...)` |
#
# When to use each:
#
# *   Use a list when you need to store a collection of items that will chang
# change frequently.
# *   Use a tuple when you need to store a collection of items that won't cha
# change and want the benefits of immutability.
#
# **Example Code**
# ```python
# # Create a list
# my_list = [1, 2, 3]
# print(my_list)  # Output: [1, 2, 3]
#
# # Modify the list
# my_list.append(4)
# print(my_list)  # Output: [1, 2, 3, 4]
#
# # Create a tuple
# my_tuple = (1, 2, 3)
# print(my_tuple)  # Output: (1, 2, 3)
#
# # Attempt to modify the tuple will raise an error
# try:
#     my_tuple.append(4)
# except AttributeError as e:
#     print(e)  # Output: 'tuple' object has no attribute 'append'
# ```
